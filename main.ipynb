# %%
import pandas as pd
data = pd.read_csv("Data UTS Kecerdasan Bisnis (20-150 dan 20-162).csv")
# df = pd.DataFrame(data)
# df
data
# Out:
#        Penyakit Jantung    BMI Perokok Aktif Peminum Alkohol Stroke  \
# 0                 Tidak  16.60            Ya           Tidak  Tidak
# 1                 Tidak  20.34         Tidak           Tidak     Ya
# 2                 Tidak  26.58            Ya           Tidak  Tidak
# 3                 Tidak  24.21         Tidak           Tidak  Tidak
# 4                 Tidak  23.71         Tidak           Tidak  Tidak
# ...                 ...    ...           ...             ...    ...
# 319790               Ya  27.41            Ya           Tidak  Tidak
# 319791            Tidak  29.84            Ya           Tidak  Tidak
# 319792            Tidak  24.24         Tidak           Tidak  Tidak
# 319793            Tidak  32.81         Tidak           Tidak  Tidak
# 319794            Tidak  46.56         Tidak           Tidak  Tidak
#
#         Kesehatan Fisik  Kesehatan Mental DiffWalking Jenis Kelamin  \
# 0                   3.0              30.0       Tidak     Perempuan
# ...

# %%
data.to_csv("Data UTS Kecerdasan Bisnis (20-150 dan 20-162).csv", sep=',')

# %%
import pandas as pd
data = pd.read_csv("Data UTS Kecerdasan Bisnis (20-150 dan 20-162).csv")
# df = pd.DataFrame(data)
# df
data
# Out:
#         Unnamed: 0.1  Unnamed: 0 Penyakit Jantung    BMI Perokok Aktif  \
# 0                  0           0            Tidak  16.60            Ya
# 1                  1           1            Tidak  20.34         Tidak
# 2                  2           2            Tidak  26.58            Ya
# 3                  3           3            Tidak  24.21         Tidak
# 4                  4           4            Tidak  23.71         Tidak
# ...              ...         ...              ...    ...           ...
# 319790        319790      319790               Ya  27.41            Ya
# 319791        319791      319791            Tidak  29.84            Ya
# 319792        319792      319792            Tidak  24.24         Tidak
# 319793        319793      319793            Tidak  32.81         Tidak
# 319794        319794      319794            Tidak  46.56         Tidak
#
#        Peminum Alkohol Stroke  Kesehatan Fisik  Kesehatan Mental DiffWalking  \
# ...

# %%
# col = ["Unnamed: 0.1","Unnamed: 0"]
# drop(columns=col)
# Out:
#        Penyakit Jantung    BMI Perokok Aktif Peminum Alkohol Stroke  \
# 0                 Tidak  16.60            Ya           Tidak  Tidak
# 1                 Tidak  20.34         Tidak           Tidak     Ya
# 2                 Tidak  26.58            Ya           Tidak  Tidak
# 3                 Tidak  24.21         Tidak           Tidak  Tidak
# 4                 Tidak  23.71         Tidak           Tidak  Tidak
# ...                 ...    ...           ...             ...    ...
# 319790               Ya  27.41            Ya           Tidak  Tidak
# 319791            Tidak  29.84            Ya           Tidak  Tidak
# 319792            Tidak  24.24         Tidak           Tidak  Tidak
# 319793            Tidak  32.81         Tidak           Tidak  Tidak
# 319794            Tidak  46.56         Tidak           Tidak  Tidak
#
#         Kesehatan Fisik  Kesehatan Mental DiffWalking Jenis Kelamin  \
# 0                   3.0              30.0       Tidak     Perempuan
# ...

# %%
df = pd.DataFrame(data)


# Langkah 2: Mengonversi Semua Kolom Menjadi Kategori dan Kemudian Menjadi Kode Kategori
df = df.apply(lambda x: pd.Categorical(x).codes)
print("\nDataFrame setelah mengubah semua kolom menjadi kode kategori:")
df
# Out:
# DataFrame setelah mengubah semua kolom menjadi kode kategori:
#         Unnamed: 0.1  Unnamed: 0  Penyakit Jantung   BMI  Perokok Aktif  \
# 0                  0           0                 0   223              1
# 1                  1           1                 0   524              0
# 2                  2           2                 0  1103              1
# 3                  3           3                 0   883              0
# 4                  4           4                 0   837              0
# ...              ...         ...               ...   ...            ...
# 319790        319790      319790                 1  1180              1
# 319791        319791      319791                 0  1397              1
# 319792        319792      319792                 0   886              0
# 319793        319793      319793                 0  1658              0
# 319794        319794      319794                 0  2700              0
#
# ...

# %%
col = ["Unnamed: 0.1","Unnamed: 0"]
df.drop(columns=col)
# Out:
#         Penyakit Jantung   BMI  Perokok Aktif  Peminum Alkohol  Stroke  \
# 0                      0   223              1                0       0
# 1                      0   524              0                0       1
# 2                      0  1103              1                0       0
# 3                      0   883              0                0       0
# 4                      0   837              0                0       0
# ...                  ...   ...            ...              ...     ...
# 319790                 1  1180              1                0       0
# 319791                 0  1397              1                0       0
# 319792                 0   886              0                0       0
# 319793                 0  1658              0                0       0
# 319794                 0  2700              0                0       0
#
#         Kesehatan Fisik  Kesehatan Mental  DiffWalking  Jenis Kelamin  \
# ...

# %%
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  Penyakit Jantung   BMI  Perokok Aktif  \
# 0                  0           0                 0   223              1
# 1                  1           1                 0   524              0
# 2                  2           2                 0  1103              1
# 3                  3           3                 0   883              0
# 4                  4           4                 0   837              0
# ...              ...         ...               ...   ...            ...
# 319790        319790      319790                 1  1180              1
# 319791        319791      319791                 0  1397              1
# 319792        319792      319792                 0   886              0
# 319793        319793      319793                 0  1658              0
# 319794        319794      319794                 0  2700              0
#
#         Peminum Alkohol  Stroke  Kesehatan Fisik  Kesehatan Mental  \
# ...

# %%
df.to_csv('data_fix.csv')
df.astype
# Out:
# <bound method NDFrame.astype of         Unnamed: 0.1  Unnamed: 0  Penyakit Jantung   BMI  Perokok Aktif  \
# 0                  0           0                 0   223              1
# 1                  1           1                 0   524              0
# 2                  2           2                 0  1103              1
# 3                  3           3                 0   883              0
# 4                  4           4                 0   837              0
# ...              ...         ...               ...   ...            ...
# 319790        319790      319790                 1  1180              1
# 319791        319791      319791                 0  1397              1
# 319792        319792      319792                 0   886              0
# 319793        319793      319793                 0  1658              0
# 319794        319794      319794                 0  2700              0
#
#         Peminum Alkohol  Stroke  Kesehatan Fisik  Kesehatan Mental  \
# ...

# %%
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  Penyakit Jantung   BMI  Perokok Aktif  \
# 0                  0           0                 0   223              1
# 1                  1           1                 0   524              0
# 2                  2           2                 0  1103              1
# 3                  3           3                 0   883              0
# 4                  4           4                 0   837              0
# ...              ...         ...               ...   ...            ...
# 319790        319790      319790                 1  1180              1
# 319791        319791      319791                 0  1397              1
# 319792        319792      319792                 0   886              0
# 319793        319793      319793                 0  1658              0
# 319794        319794      319794                 0  2700              0
#
#         Peminum Alkohol  Stroke  Kesehatan Fisik  Kesehatan Mental  \
# ...
